# %%
import numpy as np
import matplotlib.pyplot as plt

x1_09 = 2
x2_09 = 4
y1_09 = 3
y2_09 = 6

# menghitung gradien garis
m_09 = (y2_09-y1_09)/(x2_09-x1_09)

c_09 = y1_09-m_09*x1_09

#persamaan garis
print(f"Persamaan garis:y = {m_09}x + {c_09}")

# membuat array x dari -10 sampai 100
x_array_09 = np.linspace(-10,10,100)

#menghitung nilai y
y_array_09 = m_09*x_array_09+c_09

import numpy as np
import matplotlib.pyplot as plt

plt.plot(x_array_09,y_array_09)
plt.xlabel('Nilai X')
plt.ylabel('Nilai Y')
plt.title('Grafik garis')
plt.grid(True)
plt.show()
# Out:
# Persamaan garis:y = 1.5x + 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt

a_09 = 2
b_09 = 3
c_09 = 5

m_09 = -a_09/b_09
b_09 = c_09/a_09
print(f"Gradien(m_09):{m_09}")
print(f"intersep(b_09):{b_09}")

import matplotlib.pyplot as plt
def plot_graph(m_09,b_09):
    import numpy as np
x_vals_09 = np.array([-10,10])
y_vals_09 = m_09*x_vals_09 + b_09

plt.plot(x_vals_09,y_vals_09)
plt.plot(x,y_09)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Grafik persamaan garis')
plt.grid(True)
plt.show()
# Out:
# Gradien(m_09):-0.6666666666666666
# intersep(b_09):2.5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 20
#      17 y_vals_09 = m_09*x_vals_09 + b_09
#      19 plt.plot(x_vals_09,y_vals_09)
# ---> 20 plt.plot(x,y_09)
#      21 plt.xlabel('x')
#      22 plt.ylabel('y')
#
# NameError: name 'x' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
a = 2
b = 4
c = 1
x = np.linspace(-3,3,100)
y = (a*x)+(b*x)+c

plt.plot(x,y,label=f"{a}x+{b}y+{c}=0")
xlabel("x")
ylabel("y")
title("Persamaan garis")
legend()
show()

# %%
import numpy as np
import matplotlib.pyplot as plt
a_09 = 2
b_09 = 0
c_09 = 1
d_09 = 3
e_09 = 4
f_09 = 4
g_09 = 2
h_09 = 5

m_1_09 =(d_09-b_09)/(c_09-a_09)
m_2_09 =(h_09-f_09)/(g_09-e_09)
c_1_09 = -m_1_09*a_09+b_09
c_2_09 = -m_2_09*e_09+f_09

print("Persamaan garis pertama adalah y={}x+{}".format(m_1_09,c_1_09))
print("Persamaan garis kedua adalah y={}x+{}".format (m_2_09,c_2_09))

if m_1_09==m_2_09:
    if c_1_09==c_2_09:
        #print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi)
        if c_1_09 == c_2_09:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
            x=np.linspace(-5,5,100)
            plt.plot(x,m_1_09*(x-a_09)+b_09,color='red')
            plt.plot(x,m_2_09*(x-e_09)+f_09,color ='blue')
            plt.show()
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi")
            x=np.linspace(-5,5,100)
            plt.plot(x,m1_09*(x_a_09)+b,color='red')
            plt.plot(x,m_2_09*(x-e_09)+f_09,color ='blue')
            plt.show()
    else:
        print("Akan terdapat satu titik potong")
        tp_x_09 = (-m_2_09*e_09+f_09+_1_09*a_09-b_09)/(m_1_09-m_2_09)
        tp_y_09 = m_1_09*(tp_x_09-a_09)+b_09
        print("Titik potong kedua garis adalah({},{})".format(tp_x_09,tp_y_09))
        
        x=np.linspace(tp_x_09-5,tp_x_09+5,100)
        plt.plot(x,m_1_09*(x-a_09)+b_09,color = 'red')
        plt.plot(x,m_2_09*(x-e_09)+f_09,color ='blue')
        plt.axvline(x=0,color='grey')
        plt.axhline(y=0,color='grey')
        plt.show()
